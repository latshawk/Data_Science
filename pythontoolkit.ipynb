# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df= pd.read_csv('C:/Users/KevinL/Google Drive/AAPLhist.csv', 
                delimiter=',', parse_dates = True, index_col='Date')

# %%
df.head()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1857 entries, 2010-06-10 to 2017-10-23
# Data columns (total 6 columns):
# Open         1857 non-null float64
# High         1857 non-null float64
# Low          1857 non-null float64
# Close        1857 non-null float64
# Adj Close    1857 non-null float64
# Volume       1857 non-null int64
# dtypes: float64(5), int64(1)
# memory usage: 101.6 KB

# %%
plt.subplot(2,1,1)
plt.xticks(rotation=45)
plt.title('aapl 01-11')
plt.plot(df['Close'], color='blue')

view=df['Close']['2007': '2008']

plt.subplot(2,1,2)
plt.xticks(rotation= 45)
plt.title('007-08')
plt.plot(view, color='black')
plt.tight_layout()



plt.show()
